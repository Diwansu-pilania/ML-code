# %% [markdown]
# <a href="https://colab.research.google.com/github/Diwansu-pilania/ML-code/blob/main/backpack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('/content/backpack_train1.csv')

# %%
df
# Out:
#             id         Brand Material    Size  Compartments  \
# 0            0      Jansport  Leather  Medium           7.0
# 1            1      Jansport   Canvas   Small          10.0
# 2            2  Under Armour  Leather   Small           2.0
# 3            3          Nike    Nylon   Small           8.0
# 4            4        Adidas   Canvas  Medium           1.0
# ...        ...           ...      ...     ...           ...
# 299995  299995        Adidas  Leather   Small           9.0
# 299996  299996      Jansport  Leather   Large           6.0
# 299997  299997          Puma   Canvas   Large           9.0
# 299998  299998        Adidas    Nylon   Small           1.0
# 299999  299999  Under Armour   Canvas   Small           2.0
#
#        Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                     Yes         No       Tote  Black             11.611723
# 1                     Yes        Yes  Messenger  Green             27.078537
# ...

# %%
df2=pd.read_csv('/content/backpack_train2.csv')

# %%
df2
# Out:
#               id         Brand   Material    Size  Compartments  \
# 0         500000  Under Armour     Canvas   Small          10.0
# 1         500001          Puma  Polyester   Small           4.0
# 2         500002      Jansport  Polyester   Small           8.0
# 3         500003          Nike      Nylon   Large           7.0
# 4         500004          Nike    Leather   Large           9.0
# ...          ...           ...        ...     ...           ...
# 3694313  4194313          Nike     Canvas     NaN           3.0
# 3694314  4194314          Puma    Leather   Small          10.0
# 3694315  4194315      Jansport     Canvas   Large          10.0
# 3694316  4194316          Puma     Canvas     NaN           2.0
# 3694317  4194317  Under Armour  Polyester  Medium           2.0
#
#         Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                      Yes        Yes       Tote   Blue             23.882052
# ...

# %% [markdown]
# no of rows sholud be more than 1800000

# %%
df_final = pd.concat([df,df2])

# %%
df1=df_final

# %%
df1
# Out:
#               id         Brand   Material    Size  Compartments  \
# 0              0      Jansport    Leather  Medium           7.0
# 1              1      Jansport     Canvas   Small          10.0
# 2              2  Under Armour    Leather   Small           2.0
# 3              3          Nike      Nylon   Small           8.0
# 4              4        Adidas     Canvas  Medium           1.0
# ...          ...           ...        ...     ...           ...
# 3694313  4194313          Nike     Canvas     NaN           3.0
# 3694314  4194314          Puma    Leather   Small          10.0
# 3694315  4194315      Jansport     Canvas   Large          10.0
# 3694316  4194316          Puma     Canvas     NaN           2.0
# 3694317  4194317  Under Armour  Polyester  Medium           2.0
#
#         Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                      Yes         No       Tote  Black             11.611723
# ...

# %%
df1=df1.drop('id',axis=1)

# %%
df1.isnull().sum()
# Out:
# Brand                   126758
# Material                110962
# Size                     87785
# Compartments                 0
# Laptop Compartment       98533
# Waterproof               94324
# Style                   104180
# Color                   133617
# Weight Capacity (kg)      1808
# Price                        0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3994318 entries, 0 to 3694317
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Brand                 object
#  1   Material              object
#  2   Size                  object
#  3   Compartments          float64
#  4   Laptop Compartment    object
#  5   Waterproof            object
#  6   Style                 object
#  7   Color                 object
#  8   Weight Capacity (kg)  float64
#  9   Price                 float64
# dtypes: float64(3), object(7)
# memory usage: 335.2+ MB

# %%
df1['Brand'].value_counts()
# Out:
# Brand
# Under Armour    801035
# Adidas          797000
# Nike            764407
# Puma            755778
# Jansport        749340
# Name: count, dtype: int64

# %%
df1['Brand']=df1['Brand'].map({'Under Armour':1,'Adidas':2,'Nike'	:3,'Puma':4,'Jansport':5})

# %%
df1.isnull().sum()
# Out:
# Brand                   126758
# Material                110962
# Size                     87785
# Compartments                 0
# Laptop Compartment       98533
# Waterproof               94324
# Style                   104180
# Color                   133617
# Weight Capacity (kg)      1808
# Price                        0
# dtype: int64

# %%
df1['Brand']=df1['Brand'].fillna(0)

# %%
df1['Material'].unique()
# Out:
# array(['Leather', 'Canvas', 'Nylon', nan, 'Polyester'], dtype=object)

# %%
df1['Material']=df1['Material'].map({'Leather':1, 'Canvas':2, 'Nylon':3, 'nan':np.nan, 'Polyester':4})

# %%
df1.isnull().sum()
# Out:
# Brand                        0
# Material                110962
# Size                     87785
# Compartments                 0
# Laptop Compartment       98533
# Waterproof               94324
# Style                   104180
# Color                   133617
# Weight Capacity (kg)      1808
# Price                        0
# dtype: int64

# %%
df1['Material']=df1['Material'].fillna(df1['Material'].mode()[0])

# %%
df1['Size'].unique()
# Out:
# array(['Medium', 'Small', 'Large', nan], dtype=object)

# %%
df1['Size']=df1['Size'].map({'Medium':2, 'Small':1, 'Large':3})

# %%
df1['Size']=df1['Size'].fillna(df1['Size'].mode()[0])

# %%
df1['Laptop Compartment'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df1['Laptop Compartment']=df1['Laptop Compartment'].map({'Yes':1,'No':0})

# %%
df1['Laptop Compartment']=df1['Laptop Compartment'].fillna(df1['Laptop Compartment'].mode()[0])

# %%
df1['Waterproof'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df1['Waterproof']=df1['Waterproof'].map({'No':0,'Yes':1})

# %%
df1['Waterproof']=df1['Waterproof'].fillna(df1['Waterproof'].mode()[0])

# %%
df1.isnull().sum()
# Out:
# Brand                        0
# Material                     0
# Size                         0
# Compartments                 0
# Laptop Compartment           0
# Waterproof                   0
# Style                   104180
# Color                   133617
# Weight Capacity (kg)      1808
# Price                        0
# dtype: int64

# %%
df1['Style'].unique()
# Out:
# array(['Tote', 'Messenger', nan, 'Backpack'], dtype=object)

# %%
df1['Style']=df1['Style'].map({'Tote':3, 'Messenger':2, 'nan':np.nan, 'Backpack':1})

# %%
df1['Style']=df1['Style'].fillna(df1['Style'].mode()[0])

# %%
df1['Color'].unique()
# Out:
# array(['Black', 'Green', 'Red', 'Blue', 'Gray', 'Pink', nan], dtype=object)

# %%
df1['Color']=df1['Color'].map({'Black':1, 'Green':2, 'Red':3, 'Blue':4, 'Gray':5, 'Pink':6,'nan':np.nan, 'R':7})

# %%
df1['Color']=df1['Color'].fillna(df1['Color'].mode()[0])

# %%
df1['Weight Capacity (kg)']=df1['Weight Capacity (kg)'].fillna(df1['Weight Capacity (kg)'].mean())

# %%
df1.isnull().sum()
# Out:
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# Price                   0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3994318 entries, 0 to 3694317
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Brand                 float64
#  1   Material              float64
#  2   Size                  float64
#  3   Compartments          float64
#  4   Laptop Compartment    float64
#  5   Waterproof            float64
#  6   Style                 float64
#  7   Color                 float64
#  8   Weight Capacity (kg)  float64
#  9   Price                 float64
# dtypes: float64(10)
# memory usage: 335.2 MB

# %%
print(df1.isnull().sum())
# Out:
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# Price                   0
# dtype: int64

# %%
df1
# Out:
#          Brand  Material  Size  Compartments  Laptop Compartment  Waterproof  \
# 0          5.0       1.0   2.0           7.0                 1.0         0.0
# 1          5.0       2.0   1.0          10.0                 1.0         1.0
# 2          1.0       1.0   1.0           2.0                 1.0         0.0
# 3          3.0       3.0   1.0           8.0                 1.0         0.0
# 4          2.0       2.0   2.0           1.0                 1.0         1.0
# ...        ...       ...   ...           ...                 ...         ...
# 3694313    3.0       2.0   2.0           3.0                 1.0         1.0
# 3694314    4.0       1.0   1.0          10.0                 1.0         1.0
# 3694315    5.0       2.0   3.0          10.0                 0.0         0.0
# 3694316    4.0       2.0   2.0           2.0                 0.0         0.0
# 3694317    1.0       4.0   2.0           2.0                 1.0         0.0
#
# ...

# %%
y=df1['Price']

# %%
x=df1.drop('Price',axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=10, max_depth=10, n_jobs=-1)
rf.fit(x, y)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=10, n_jobs=-1)

# %%
df_test=pd.read_csv('/content/backpack_test.csv')

# %%
df_test
# Out:
#             id         Brand   Material    Size  Compartments  \
# 0       300000          Puma    Leather   Small           2.0
# 1       300001          Nike     Canvas  Medium           7.0
# 2       300002        Adidas     Canvas   Large           9.0
# 3       300003        Adidas      Nylon   Large           1.0
# 4       300004           NaN      Nylon   Large           2.0
# ...        ...           ...        ...     ...           ...
# 199995  499995        Adidas     Canvas   Large           2.0
# 199996  499996          Nike  Polyester   Small           9.0
# 199997  499997      Jansport      Nylon   Small           9.0
# 199998  499998          Puma      Nylon   Large          10.0
# 199999  499999  Under Armour    Leather  Medium           8.0
#
#        Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)
# 0                      No         No       Tote  Green             20.671147
# ...

# %%
import numpy as np

df_test['Color'] = df_test['Color'].map({'Black':1, 'Green':2, 'Red':3, 'Blue':4,
                                         'Gray':5, 'Pink':6, 'nan':np.nan, 'R':7})

df_test['Style'] = df_test['Style'].map({'Tote':3, 'Messenger':2, 'nan':np.nan, 'Backpack':1})

df_test['Waterproof'] = df_test['Waterproof'].map({'No':0, 'Yes':1})

df_test['Laptop Compartment'] = df_test['Laptop Compartment'].map({'Yes':1, 'No':0})

df_test['Size'] = df_test['Size'].map({'Medium':2, 'Small':1, 'Large':3})

df_test['Material'] = df_test['Material'].map({'Leather':1, 'Canvas':2, 'Nylon':3,
                                               'nan':np.nan, 'Polyester':4})

df_test['Brand'] = df_test['Brand'].map({'Under Armour':1, 'Adidas':2, 'Nike':3,
                                         'Puma':4, 'Jansport':5})

df_test['Weight Capacity (kg)'] = df_test['Weight Capacity (kg)'].fillna(df_test['Weight Capacity (kg)'].mean())

df_test['Color'] = df_test['Color'].fillna(df_test['Color'].mode()[0])
df_test['Style'] = df_test['Style'].fillna(df_test['Style'].mode()[0])

# %%
df_test.isnull().sum()
# Out:
# id                         0
# Brand                   6227
# Material                5613
# Size                    4381
# Compartments               0
# Laptop Compartment      4962
# Waterproof              4811
# Style                      0
# Color                      0
# Weight Capacity (kg)       0
# dtype: int64

# %%
df_test['Waterproof'] = df_test['Waterproof'].fillna(df_test['Waterproof'].mode()[0])
df_test['Laptop Compartment'] = df_test['Laptop Compartment'].fillna(df_test['Laptop Compartment'].mode()[0])
df_test['Size'] = df_test['Size'].fillna(df_test['Size'].mode()[0])
df_test['Material'] = df_test['Material'].fillna(df_test['Material'].mode()[0])
df_test['Brand'] = df_test['Brand'].fillna(0)

# %%
df_test.isnull().sum()
# Out:
# id                      0
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# dtype: int64

# %%
id = df_test['id']

# %%
df_test=df_test.drop('id',axis=1)

# %%
df_test
# Out:
#         Brand  Material  Size  Compartments  Laptop Compartment  Waterproof  \
# 0         4.0       1.0   1.0           2.0                 0.0         0.0
# 1         3.0       2.0   2.0           7.0                 0.0         1.0
# 2         2.0       2.0   3.0           9.0                 0.0         1.0
# 3         2.0       3.0   3.0           1.0                 1.0         0.0
# 4         0.0       3.0   3.0           2.0                 1.0         1.0
# ...       ...       ...   ...           ...                 ...         ...
# 199995    2.0       2.0   3.0           2.0                 1.0         0.0
# 199996    3.0       4.0   1.0           9.0                 0.0         1.0
# 199997    5.0       3.0   1.0           9.0                 0.0         1.0
# 199998    4.0       3.0   3.0          10.0                 1.0         0.0
# 199999    1.0       1.0   2.0           8.0                 1.0         1.0
#
#         Style  Color  Weight Capacity (kg)
# ...

# %%
y_lr_pre=lr.predict(df_test)

# %%
y_lr_pre
# Out:
# array([81.00667918, 80.38344704, 80.49949786, ..., 82.16892527,
#        82.62225487, 81.95416879])

# %%
y_rf_pre=rf.predict(df_test)

# %%
y_rf_pre
# Out:
# array([81.53550763, 82.72059799, 81.98639194, ..., 82.68277952,
#        82.36092416, 81.26316726])

# %%
result_lr=pd.DataFrame(y_lr_pre,columns=['Price'])

# %%
result_rf=pd.DataFrame(y_rf_pre,columns=['Price'])

# %%
result_lr=pd.concat([id,result_lr],axis=1)

# %%
result_rf=pd.concat([id,result_rf],axis=1)

# %%
result_lr.to_csv('result_lr.csv',index=False)

# %%
result_rf.to_csv('result_rf.csv',index=False)

# %%
result_rf
# Out:
#             id      Price
# 0       300000  81.535508
# 1       300001  82.720598
# 2       300002  81.986392
# 3       300003  81.688786
# 4       300004  92.792184
# ...        ...        ...
# 199995  499995  80.404126
# 199996  499996  77.982233
# 199997  499997  82.682780
# 199998  499998  82.360924
# 199999  499999  81.263167
#
# [200000 rows x 2 columns]
